# %%
# !git clone https://github.com/spinspincoupling/cs486_project.git

# %%
# !unzip /content/cs486_project/data/diving.zip

# %%
# %cd /content/cs486_project
import train 
train.main()
